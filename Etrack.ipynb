# %%
pip install pandas openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os

# Define the directory containing the pre-survey files
pre_dir = "/Users/saitejasriyerramsetti/Library/CloudStorage/GoogleDrive-saitejasriy10@gmail.com/My Drive/Zip LaunchPad/E- Track/Pre"
output_file = "Merged_Pre_Survey_Data.csv"

# Initialize an empty list to store dataframes
pre_survey_dfs = []

# Loop through all files in the directory
for file in os.listdir(pre_dir):
    if file.endswith(".xlsx"):
        file_path = os.path.join(pre_dir, file)
        # Read the Excel file into a DataFrame
        df = pd.read_excel(file_path)
        # Add a column for the filename (optional, for tracking purposes)
        df['Source File'] = file
        # Append the DataFrame to the list
        pre_survey_dfs.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
combined_pre_survey_data = pd.concat(pre_survey_dfs, ignore_index=True)

# Save the combined DataFrame to a CSV file
combined_pre_survey_data.to_csv(output_file, index=False)

print(f"All files from {pre_dir} have been merged into {output_file}")
# Out:
# All files from /Users/saitejasriyerramsetti/Library/CloudStorage/GoogleDrive-saitejasriy10@gmail.com/My Drive/Zip LaunchPad/E- Track/Pre have been merged into Merged_Pre_Survey_Data.csv

# %%
df = pd.read_csv("/Users/saitejasriyerramsetti/Library/CloudStorage/GoogleDrive-saitejasriy10@gmail.com/My Drive/Zip LaunchPad/E- Track/Notebooks/Merged_Pre_Survey_Data.csv")

# %%
df = df.iloc[:, :-1]

# %%
df['Year'] = pd.to_datetime(df['Timestamp']).dt.year

# %%
df.head()
# Out:
#                  Timestamp  Season Survey  \
# 0  2023-02-16 17:56:18.376  Spring    Pre
# 1  2023-02-16 18:09:25.838  Spring    Pre
# 2  2023-02-16 23:43:57.709  Spring    Pre
# 3  2023-02-16 23:54:03.592  Spring    Pre
# 4  2023-02-17 00:56:06.471  Spring    Pre
#
#    Ability to make high impact presentations    \
# 0                                            6
# 1                                            7
# 2                                            3
# 3                                            7
# 4                                            6
#
#    Ability to effectively network resulting in meaningful contacts  \
# 0                                                  5
# 1                                                  7
# 2                                                  5
# 3                                                  7
# 4                                                 10
#
# ...

# %%
import pandas as pd
import os

# Define the directory containing the pre-survey files
pre_dir = "/Users/saitejasriyerramsetti/Library/CloudStorage/GoogleDrive-saitejasriy10@gmail.com/My Drive/Zip LaunchPad/E- Track/Post"
output_file = "Merged_Post_Survey_Data.csv"

# Initialize an empty list to store dataframes
pre_survey_dfs = []

# Loop through all files in the directory
for file in os.listdir(pre_dir):
    if file.endswith(".xlsx"):
        file_path = os.path.join(pre_dir, file)
        # Read the Excel file into a DataFrame
        df = pd.read_excel(file_path)
        # Add a column for the filename (optional, for tracking purposes)
        df['Source File'] = file
        # Append the DataFrame to the list
        pre_survey_dfs.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
combined_pre_survey_data = pd.concat(pre_survey_dfs, ignore_index=True)

# Save the combined DataFrame to a CSV file
combined_pre_survey_data.to_csv(output_file, index=False)

print(f"All files from {pre_dir} have been merged into {output_file}")
# Out:
# All files from /Users/saitejasriyerramsetti/Library/CloudStorage/GoogleDrive-saitejasriy10@gmail.com/My Drive/Zip LaunchPad/E- Track/Post have been merged into Merged_Post_Survey_Data.csv

# %%
df1 = pd.read_csv("/Users/saitejasriyerramsetti/Library/CloudStorage/GoogleDrive-saitejasriy10@gmail.com/My Drive/Zip LaunchPad/E- Track/Notebooks/Merged_Post_Survey_Data.csv")
df1 = df1.iloc[:, :-1]
df1['Year'] = pd.to_datetime(df1['Timestamp']).dt.year

# %%
df = pd.read_csv("/Users/syerramsetti9523/Zip LaunchPad/E- Track/Notebooks/Merged_Pre_Survey_Data.csv")
df = df.iloc[:, :-1]
df['Year'] = pd.to_datetime(df['Timestamp']).dt.year
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_csv("/Users/syerramsetti9523/Zip LaunchPad/E- Track/Notebooks/Merged_Pre_Survey_Data.csv")
#       2 df = df.iloc[:, :-1]
#       3 df['Year'] = pd.to_datetime(df['Timestamp']).dt.year
#
# ...

# %%
df1.head()
# Out:
#                  Timestamp  Season Survey  \
# 0  2022-08-29 16:47:40.728  Summer   Post
# 1  2022-08-29 18:12:29.395  Summer   Post
# 2  2022-08-30 14:00:05.142  Summer   Post
# 3  2022-09-07 10:19:27.432  Summer   Post
# 4  2022-09-07 14:47:16.244  Summer   Post
#
#    Ability to make high impact presentations    \
# 0                                            8
# 1                                            8
# 2                                            9
# 3                                           10
# 4                                            8
#
#    Ability to effectively network resulting in meaningful contacts  \
# 0                                                  8
# 1                                                 10
# 2                                                  3
# 3                                                 10
# 4                                                  7
#
# ...

# %%
df1 = df1[['Timestamp', 'Season', 'Survey','Source File', 'Year',
       'Ability to make high impact presentations  ',
       'Ability to effectively network resulting in meaningful contacts',
       'Ability to capitalize on new contacts to help support your entrepreneurial efforts',
       'Ability to make evidence based decisions',
       'Ability to listen and incorporate feedback', 'Ability to manage time',
       'Ability to make decisions and drive a path forward in an environment of uncertainty',
       'Ability to scope resources needed to execute on your idea ',
       'Ability to recruit necessary team members to execute on your idea',
       'Your interest in entrepreneurship in general',
       'Your interest in being part of a startup some time in your career ',
       'Your value of having experience based entrepreneurial learning to your career/professionally ',
       'Your value of having experience based entrepreneurial learning to you personally',
       'What are your personal goals and/or expectations after  completing the E-Track?',
       'How have your personal goals and/or expectations concerning your potential future involvement in the ZIP Launchpad changed after E-Track?'
       ]]

# %%
df1['Ability to make high impact presentations  ']
# Out:
# 0      8
# 1      8
# 2      9
# 3     10
# 4      8
#       ..
# 70     8
# 71     8
# 72    10
# 73     8
# 74     9
# Name: Ability to make high impact presentations  , Length: 75, dtype: int64

# %%
df = df[['Timestamp', 'Season', 'Survey','Source File', 'Year',
       'Ability to make high impact presentations  ',
       'Ability to effectively network resulting in meaningful contacts',
       'Ability to capitalize on new contacts to help support your entrepreneurial efforts',
       'Ability to make evidence based decisions',
       'Ability to listen and incorporate feedback', 'Ability to manage time',
       'Ability to make decisions and drive a path forward in an environment of uncertainty',
       'Ability to scope resources needed to execute on your idea ',
       'Ability to recruit necessary team members to execute on your idea',
       'Your interest in entrepreneurship in general',
       'Your interest in being part of a startup some time in your career ',
       'Your value of having experience based entrepreneurial learning to your career/professionally ',
       'Your value of having experience based entrepreneurial learning to you personally',
       'What are your personal goals and/or expectations concerning your involvement in E-Track?',
       'What are your personal goals and/or expectations concerning your potential future involvement in the ZIP Launchpad?'
       ]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = df[['Timestamp', 'Season', 'Survey','Source File', 'Year',
#       2        'Ability to make high impact presentations  ',
#       3        'Ability to effectively network resulting in meaningful contacts',
#       4        'Ability to capitalize on new contacts to help support your entrepreneurial efforts',
#       5        'Ability to make evidence based decisions',
#       6        'Ability to listen and incorporate feedback', 'Ability to manage time',
#       7        'Ability to make decisions and drive a path forward in an environment of uncertainty',
#       8        'Ability to scope resources needed to execute on your idea ',
#       9        'Ability to recruit necessary team members to execute on your idea',
#      10        'Your interest in entrepreneurship in general',
# ...

# %%
a= df.columns[5:-2]
a
# Out:
# Index(['Ability to capitalize on new contacts to help support your entrepreneurial efforts',
#        'Ability to make evidence based decisions',
#        'Ability to listen and incorporate feedback', 'Ability to manage time',
#        'Ability to make decisions and drive a path forward in an environment of uncertainty',
#        'Ability to scope resources needed to execute on your idea ',
#        'Ability to recruit necessary team members to execute on your idea',
#        'Your interest in entrepreneurship in general',
#        'Your interest in being part of a startup some time in your career ',
#        'Your value of having experience based entrepreneurial learning to your career/professionally ',
#        'Your value of having experience based entrepreneurial learning to you personally',
#        'What are your personal goals and/or expectations after  completing the E-Track?'],
#       dtype='object')

# %%
df['Survey'] = df['Survey'].fillna('Pre')

# %%
df1['Survey'] = df1['Survey'].fillna('Post')

# %%
import re

def extract_season(source_file):
    seasons = ['Spring', 'Summer', 'Fall', 'Winter']
    for season in seasons:
        if re.search(season, source_file, re.IGNORECASE):
            return season
    return None

df['Extracted_Season'] = df['Source File'].apply(extract_season)
df['Season'] = df['Season'].fillna(df['Extracted_Season'])
df.drop(columns=['Extracted_Season'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                                    0
# Season                                                                                                                                       0
# Survey                                                                                                                                       0
# Ability to make high impact presentations                                                                                                    0
# Ability to effectively network resulting in meaningful contacts                                                                              0
# Ability to capitalize on new contacts to help support your entrepreneurial efforts                                                           0
# ...

# %%
df1.isnull().sum()
# Out:
# Timestamp                                                                                                                                     0
# Season                                                                                                                                        0
# Survey                                                                                                                                        0
# Source File                                                                                                                                   0
# Year                                                                                                                                          0
# Ability to make high impact presentations                                                                                                     0
# ...

# %%
summary_stats_pre_whole = df['Ability to make high impact presentations  '].agg(['mean', 'std'])
print("Pre-survey Whole Dataset Summary Statistics:")
print(summary_stats_pre_whole)
# Out:
# Pre-survey Whole Dataset Summary Statistics:
# mean    9.0
# std     1.0
# Name: Ability to make high impact presentations  , dtype: float64

# %%
def mean_and_std(df,df1,column):
    n_col = len(column)
    for i in range(n_col):
        mean_df = df[column[i]].describe()['mean']
        mean_df1 = df1[column[i]].describe()['mean']
        std_df = df[column[i]].describe()['std']
        std_df1 = df1[column[i]].describe()['std']
        print("Overall comparison of mena and Standardar deviation of pre and post survey data")
        print("#############################################################################")
        print(column[i])
        print("Pre-Survey mean and standard Deviation                    Post-Survey mean and standard Deviation")
        print("#############################################################################")
        print(f"Mean(pre) : {mean_df:.2f}     Standard Deviation(pre)  : {std_df:.2f}            Mean(post) : {mean_df1:.2f}     Standard Deviation(post)  : {std_df1:.2f}\n")

# %%
mean_and_std(df,df1,a)
# Out:
# Overall comparison of mena and Standardar deviation of pre and post survey data
# #############################################################################
# Ability to capitalize on new contacts to help support your entrepreneurial efforts
# Pre-Survey mean and standard Deviation                    Post-Survey mean and standard Deviation
# #############################################################################
# Mean(pre) : 8.00     Standard Deviation(pre)  : 1.00            Mean(post) : 7.63     Standard Deviation(post)  : 1.69
#
# Overall comparison of mena and Standardar deviation of pre and post survey data
# #############################################################################
# Ability to make evidence based decisions
# Pre-Survey mean and standard Deviation                    Post-Survey mean and standard Deviation
# #############################################################################
# ...

# %%
df1.describe()
# Out:
#               Year  Ability to make high impact presentations    \
# count    75.000000                                    75.000000
# mean   2022.160000                                     8.146667
# std       1.027198                                     1.682126
# min    2021.000000                                     1.000000
# 25%    2021.000000                                     8.000000
# 50%    2022.000000                                     8.000000
# 75%    2023.000000                                     9.000000
# max    2024.000000                                    10.000000
#
#        Ability to effectively network resulting in meaningful contacts  \
# count                                          75.000000
# mean                                            7.760000
# std                                             1.626138
# min                                             3.000000
# 25%                                             7.000000
# ...

# %%
df.describe()
# Out:
#                            Timestamp  \
# count                              3
# mean   2021-08-13 16:58:22.811333376
# min       2021-08-09 21:13:37.144000
# 25%       2021-08-11 18:48:20.472000
# 50%       2021-08-13 16:23:03.800000
# 75%    2021-08-15 14:50:45.644999936
# max       2021-08-17 13:18:27.490000
# std                              NaN
#
#        Ability to make high impact presentations    \
# count                                          3.0
# mean                                           9.0
# min                                            8.0
# 25%                                            8.5
# 50%                                            9.0
# 75%                                            9.5
# max                                           10.0
# std                                            1.0
#
#        Ability to effectively network resulting in meaningful contacts  \
# count                                                3.0
# ...

# %% [markdown]
# # SEASON AND YEAR WISE SURVEY

# %%
print(df[(df['Year'] == 2021) & (df['Season'] == "Fall")]['Ability to make high impact presentations  '].describe()['mean'])
Fall_2021_post = df1[(df1['Year'] == 2021) & (df1['Season'] == "Fall")]
#df1['Ability to make high impact presentations  '].describe()[1:2]
#Fall_2021_pre
Year=[2020, 2021, 2022, 2023, 2024]
Season =  ['Fall','Summer', 'Spring']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ...

# %%
def season_and_year(df,df1,column):
    n_col = len(column)
    for i in range(n_col):
        mean_df = df[(df['Year'] == 2021) & (df['Season'] == "Fall")][column[i]].describe()['mean']
        mean_df1 = df1[(df1['Year'] == 2021) & (df1['Season'] == "Fall")][column[i]].describe()['mean']
        std_df = df[(df['Year'] == 2021) & (df['Season'] == "Fall")][column[i]].describe()['std']
        std_df1 = df1[(df1['Year'] == 2021) & (df1['Season'] == "Fall")][column[i]].describe()['std']
        print("Overall comparison of mean and Standard deviation of pre and post survey data  Fall - 2021")
        print("#############################################################################")
        print(column[i])
        print("Pre-Survey mean and standard Deviation                    Post-Survey mean and standard Deviation")
        print("#############################################################################")
        print(f"Mean(pre) : {mean_df:.2f}     Standard Deviation(pre)  : {std_df:.2f}            Mean(post) : {mean_df1:.2f}     Standard Deviation(post)  : {std_df1:.2f}\n")

season_and_year(df,df1,a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 15
# ...

# %%
import pandas as pd

def season_and_year(df, df1, columns, years, seasons,output_file):
    # Initialize an empty list to store results
    results = []

    for year in years:
        for season in seasons:
            for column in columns:
                # Calculate mean and standard deviation for pre-survey data
                mean_df = df[(df['Year'] == year) & (df['Season'] == season)][column].describe()['mean']
                std_df = df[(df['Year'] == year) & (df['Season'] == season)][column].describe()['std']
                
                # Calculate mean and standard deviation for post-survey data
                mean_df1 = df1[(df1['Year'] == year) & (df1['Season'] == season)][column].describe()['mean']
                std_df1 = df1[(df1['Year'] == year) & (df1['Season'] == season)][column].describe()['std']
                
                # Append results to the list
                results.append({
                    'Year': year,
                    'Season': season,
                    'Column': column,
                    'Pre-Survey Mean': mean_df,
                    'Pre-Survey Std Dev': std_df,
                    'Post-Survey Mean': mean_df1,
                    'Post-Survey Std Dev': std_df1
                })

    # Convert the results list to a DataFrame
    results_df = pd.DataFrame(results)
    
    # Pivot the DataFrame to have columns for each statistic
    pivot_table = results_df.pivot_table(
        index=['Year', 'Season', 'Column'],
        values=['Pre-Survey Mean', 'Pre-Survey Std Dev', 'Post-Survey Mean', 'Post-Survey Std Dev'],
        aggfunc='first'
    ).reset_index()
    
    # Print the pivot table
    print(pivot_table.to_string(index=False))
    pivot_table.to_csv(output_file, index=False)
    print(f"Pivot table saved to {output_file}")

# Define the columns, years, and seasons


# Call the function
season_and_year(df, df1, a, Year, Season,"Season_year_pre_post.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 48
#      42     print(f"Pivot table saved to {output_file}")
#      44 # Define the columns, years, and seasons
#      45
#      46
#      47 # Call the function
# ---> 48 season_and_year(df, df1, a, Year, Season,"Season_year_pre_post.csv")
#
# NameError: name 'Year' is not defined

# %%
data_post = pd.read_csv("/Users/saitejasriyerramsetti/Library/CloudStorage/GoogleDrive-saitejasriy10@gmail.com/My Drive/Zip LaunchPad/E- Track/Notebooks/Merged_Post_Survey_Data.csv")
data_pre = pd.read_csv("/Users/saitejasriyerramsetti/Library/CloudStorage/GoogleDrive-saitejasriy10@gmail.com/My Drive/Zip LaunchPad/E- Track/Notebooks/Merged_Pre_Survey_Data.csv")

# %%
data_post.head()
# Out:
#                  Timestamp  Season Survey  \
# 0  2022-08-29 16:47:40.728  Summer   Post
# 1  2022-08-29 18:12:29.395  Summer   Post
# 2  2022-08-30 14:00:05.142  Summer   Post
# 3  2022-09-07 10:19:27.432  Summer   Post
# 4  2022-09-07 14:47:16.244  Summer   Post
#
#    Ability to make high impact presentations    \
# 0                                            8
# 1                                            8
# 2                                            9
# 3                                           10
# 4                                            8
#
#    Ability to effectively network resulting in meaningful contacts  \
# 0                                                  8
# 1                                                 10
# 2                                                  3
# 3                                                 10
# 4                                                  7
#
# ...

# %%
data_post['How have your personal goals and/or expectations concerning your potential future involvement in the ZIP Launchpad changed after E-Track?'][0]
# Out:
# "more focused and I clearly understand the essential nature of starting with a problem (NOT a solution) and gathering information from prospective customers BEFORE creating a solution. That's pretty valuable information!! :)"
